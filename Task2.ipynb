# %%
def isPrime(num):
    
    if num > 1:
        for n in range(2,int(num**1/2)+1):
            if num%n==0:
                return False
    else:
        return false
        

i = 0
primes = []

while True:
    if isPrime(i):
        if sum(primes) + i > 1000000:
            break
        
        primes.append(i)
    
    i += 1
    
max = 0
total = 0
    
for i in range(len(primes)):
    for j in range(i,len(primes) + 1):
        if isPrime(sum(primes[i:j])):
            if j - i > max:
                max = j - i
                total = sum(primes[i:j])
                
print(max)
print(total)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b6de8550fa71> in <module>
#       3
#       4 while True:
# ----> 5     if isPrime(i):
#       6         if sum(primes) + i > 1000000:
#       7             break
#
# NameError: name 'isPrime' is not defined
