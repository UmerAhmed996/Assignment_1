# %%
class Queue:
  
    def __init__(this, maxSize):
        this.queue = list()
        this.maxSize = maxSize
        this.front = -1
        this.rear = -1
        this.count = 0

    def isFull(this):
        if this.getSize() == this.maxSize:
            return True
        else:
            return False
    
    def isEmpty(this):
        if this.getSize() == 0:
            return True
        else:
            return False

    def getSize(this):
        return this.count

        
    def EnQueue(this, data):
    
        if this.isFull():
            print("queue is full")
        else:
            this.queue.append(data)
            this.rear = (this.rear+1) % this.maxSize
            this.count += 1
        return True
  
    def DeQueue(this):
    
        if this.isEmpty():
            print("queue is empty!")
        else:
            data = this.queue[this.front]
            this.head = (this.front+1) % this.maxSize
            this.count -= 1
            return data
      
    def minimum(this):
        Min = 0
        if(this.isEmpty()):
            print('queue is Empty!')
        else:
            arr = this.queue
            Min = min(arr)
            return Min
        return True

queue = Queue(5)
value = 0

queue.EnQueue(1)
queue.EnQueue(2)
queue.EnQueue(3)
queue.EnQueue(4)
queue.EnQueue(5)
    
print(queue.minimum())
# Out:
# 1
